# %%
import random
import matplotlib.pyplot as plt

t = list(range(50))
y = [0]
current = 0
for i in t[1:]:
    current = current + random.randint(0,1)*2-1
    y.append(current)

plt.plot(t,y)
plt.show()
